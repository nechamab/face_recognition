# %% [markdown]
# # Face Recognition: Siamese Network

# %% [markdown]
# # Setup

# %%
import random
import numpy as np
import keras
from keras import backend as K
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_olivetti_faces
from sklearn.model_selection import train_test_split
import pandas as pd

# %% [markdown]
# # Hyperparameters

# %%
epochs = 10
batch_size = 16
margin = 1  # Margin for contrastive loss.

# %% [markdown]
# # Load the Olivetti dataset

# %%
data = fetch_olivetti_faces()
face_images = data.images
face_labels = data.target

x_train_val, x_test, y_train_val, y_test = train_test_split(
    face_images, face_labels, test_size=0.2, random_state=42
)

# Change the data type to a floating point format
x_train_val = x_train_val.astype("float32")
x_test = x_test.astype("float32")

print("X_train shape:",x_train_val.shape)
print("y_train shape:{}".format(y_train_val.shape))
# Out:
# X_train shape: (320, 64, 64)
# y_train shape:(320,)

# %% [markdown]
# Some information about the dataset.

# %%
print("There are {} images in the dataset".format(len(face_images)))
print("There are {} unique targets in the dataset".format(len(np.unique(face_labels))))
print("Size of each image is {}x{}".format(face_images.shape[1],face_images.shape[2]))
print("Pixel values were scaled to [0,1] interval. e.g:{}".format(face_images[0][0,:4]))
# Out:
# There are 400 images in the dataset
# There are 40 unique targets in the dataset
# Size of each image is 64x64
# Pixel values were scaled to [0,1] interval. e.g:[0.30991736 0.3677686  0.41735536 0.44214877]

# %%
def show_40_distinct_people(images, unique_ids):
    #Creating 4X10 subplots in  18x9 figure size
    fig, axarr=plt.subplots(nrows=4, ncols=10, figsize=(18, 9))
    #For easy iteration flattened 4X10 subplots matrix to 40 array
    axarr=axarr.flatten()
    
    #iterating over user ids
    for unique_id in unique_ids:
        image_index=unique_id*10
        axarr[unique_id].imshow(images[image_index], cmap='gray')
        axarr[unique_id].set_xticks([])
        axarr[unique_id].set_yticks([])
        axarr[unique_id].set_title("face id:{}".format(unique_id))
    plt.suptitle("There are 40 distinct people in the dataset")

# %%
show_40_distinct_people(face_images, np.unique(face_labels))

# %% [markdown]
# ## Class Distribution

# %%
y_frame=pd.DataFrame()
y_frame['subject ids']=face_labels
y_frame.groupby(['subject ids']).size().plot.bar(figsize=(15,8),title="Number of Samples for Each Classes")
# Out:
# <Axes: title={'center': 'Number of Samples for Each Classes'}, xlabel='subject ids'>

# %% [markdown]
# # Define training and validation sets

# %%
len(x_train_val)
# Out:
# 320

# %%
# Keep 50% of train_val  in validation set
x_train, x_val = x_train_val[:160], x_train_val[160:]
y_train, y_val = y_train_val[:160], y_train_val[160:]
del x_train_val, y_train_val

# %% [markdown]
# # Create pairs of images

# %%
def make_pairs(x, y):
    """Creates a tuple containing image pairs with corresponding label.

    Arguments:
        x: List containing images, each index in this list corresponds to one image.
        y: List containing labels, each label with datatype of `int`.

    Returns:
        Tuple containing two numpy arrays as (pairs_of_samples, labels),
        where pairs_of_samples' shape is (2len(x), 2,n_features_dims) and
        labels are a binary array of shape (2len(x)).
    """

    num_classes = max(y) + 1
    digit_indices = [np.where(y == i)[0] for i in range(num_classes)]
    
    pairs = []
    labels = []

    for idx1 in range(len(x)):
        # add a matching example
        x1 = x[idx1]
        label1 = y[idx1]
        idx2 = random.choice(digit_indices[label1])
        x2 = x[idx2]

        pairs += [[x1, x2]]
        labels += [0]

        # add a non-matching example
        label2 = random.randint(0, num_classes - 1)
        while label2 == label1 or len(digit_indices[label2]) == 0:
            label2 = random.randint(0, num_classes - 1)

        idx2 = random.choice(digit_indices[label2])
        x2 = x[idx2]

        pairs += [[x1, x2]]
        labels += [1]

    return np.array(pairs), np.array(labels).astype("float32")


# make train pairs
pairs_train, labels_train = make_pairs(x_train, y_train)

# make validation pairs
pairs_val, labels_val = make_pairs(x_val, y_val)

# make test pairs
pairs_test, labels_test = make_pairs(x_test, y_test)

# %%
def make_pairs(x, y):
    num_classes = max(y) + 1
    digit_indices = [np.where(y == i)[0] for i in range(num_classes)]

    pairs = []
    labels = []

    for idx1 in range(len(x)):
        x1 = x[idx1]
        label1 = y[idx1]
        idx2 = random.choice(digit_indices[label1])
        x2 = x[idx2]

        pairs += [[x1, x2]]
        labels += [0]

        label2 = random.randint(0, num_classes - 1)
        while label2 == label1 or len(digit_indices[label2]) == 0:
            label2 = random.randint(0, num_classes - 1)

        idx2 = random.choice(digit_indices[label2])
        x2 = x[idx2]

        pairs += [[x1, x2]]
        labels += [1]

    return np.array(pairs), np.array(labels).astype("float32")


# make train pairs
pairs_train, labels_train = make_pairs(x_train, y_train)

# make validation pairs
pairs_val, labels_val = make_pairs(x_val, y_val)

# make test pairs
pairs_test, labels_test = make_pairs(x_test, y_test)

# %%
x_train_1 = pairs_train[:, 0]  # x_train_1.shape is (320, 64, 64)
x_train_2 = pairs_train[:, 1]

# %%
x_val_1 = pairs_val[:, 0]  # x_val_1.shape = (320, 64, 64)
x_val_2 = pairs_val[:, 1]

# %%
x_test_1 = pairs_test[:, 0]  # x_test_1.shape = (160, 64, 64)
x_test_2 = pairs_test[:, 1]

# %% [markdown]
# # Visualize pairs and their labels

# %%
def visualize(pairs, labels, to_show=6, num_col=3, predictions=None, test=False):
    """Creates a plot of pairs and labels, and prediction if it's test dataset.

    Arguments:
        pairs: Numpy Array, of pairs to visualize, having shape
               (Number of pairs, 2, 28, 28).
        to_show: Int, number of examples to visualize (default is 6)
                `to_show` must be an integral multiple of `num_col`.
                 Otherwise it will be trimmed if it is greater than num_col,
                 and incremented if if it is less then num_col.
        num_col: Int, number of images in one row - (default is 3)
                 For test and train respectively, it should not exceed 3 and 7.
        predictions: Numpy Array of predictions with shape (to_show, 1) -
                     (default is None)
                     Must be passed when test=True.
        test: Boolean telling whether the dataset being visualized is
              train dataset or test dataset - (default False).

    Returns:
        None.
    """

    # Define num_row
    # If to_show % num_col != 0
    #    trim to_show,
    #       to trim to_show limit num_row to the point where
    #       to_show % num_col == 0
    #
    # If to_show//num_col == 0
    #    then it means num_col is greater then to_show
    #    increment to_show
    #       to increment to_show set num_row to 1
    num_row = to_show // num_col if to_show // num_col != 0 else 1

    # `to_show` must be an integral multiple of `num_col`
    #  we found num_row and we have num_col
    #  to increment or decrement to_show
    #  to make it integral multiple of `num_col`
    #  simply set it equal to num_row * num_col
    to_show = num_row * num_col

    # Plot the images
    fig, axes = plt.subplots(num_row, num_col, figsize=(5, 5))
    for i in range(to_show):
        # If the number of rows is 1, the axes array is one-dimensional
        if num_row == 1:
            ax = axes[i % num_col]
        else:
            ax = axes[i // num_col, i % num_col]

            # Ensure the pairs are properly formatted
        pair_to_show = np.concatenate([pairs[i][0], pairs[i][1]], axis=1)

        ax.imshow(pair_to_show, cmap="gray")
        ax.set_axis_off()
        if test:
            ax.set_title("True: {} | Pred: {:.5f}".format(labels[i], predictions[i][0]))
        else:
            ax.set_title("Label: {}".format(labels[i]))
    if test:
        plt.tight_layout(rect=(0, 0, 1.9, 1.9), w_pad=0.0)
    else:
        plt.tight_layout(rect=(0, 0, 1.5, 1.5))
    plt.show()

# %%
visualize(pairs_train[:-1], labels_train[:-1], to_show=4, num_col=4)

# %%
visualize(pairs_val[:-1], labels_val[:-1], to_show=4, num_col=4)

# %%
visualize(pairs_test[:-1], labels_test[:-1], to_show=4, num_col=4)

# %% [markdown]
# # Define Model

# %%
# Provided two tensors t1 and t2
# Euclidean distance = sqrt(sum(square(t1-t2)))
def euclidean_distance(vects):
    """Find the Euclidean distance between two vectors.

    Arguments:
        vects: List containing two tensors of same length.

    Returns:
        Tensor containing euclidean distance
        (as floating point value) between vectors.
    """

    x, y = vects
    sum_square = K.sum(K.square(x - y), axis=1, keepdims=True)
    return K.sqrt(K.maximum(sum_square, K.epsilon()))


input = keras.layers.Input((64, 64, 1))
x = keras.layers.BatchNormalization()(input)
x = keras.layers.Conv2D(4, (5, 5), activation="relu")(x)
x = keras.layers.AveragePooling2D(pool_size=(2, 2))(x)
x = keras.layers.Conv2D(16, (5, 5), activation="relu")(x)
x = keras.layers.AveragePooling2D(pool_size=(2, 2))(x)
x = keras.layers.Flatten()(x)

x = keras.layers.BatchNormalization()(x)
x = keras.layers.Dense(10, activation="relu")(x)
embedding_network = keras.Model(input, x)


input_1 = keras.layers.Input((64, 64, 1))
input_2 = keras.layers.Input((64, 64, 1))

# As mentioned above, Siamese Network share weights between
# tower networks (sister networks). To allow this, we will use
# same embedding network for both tower networks.
tower_1 = embedding_network(input_1)
tower_2 = embedding_network(input_2)

merge_layer = keras.layers.Lambda(euclidean_distance, output_shape=(1,))(
    [tower_1, tower_2]
)
normal_layer = keras.layers.BatchNormalization()(merge_layer)
output_layer = keras.layers.Dense(1, activation="sigmoid")(normal_layer)
siamese = keras.Model(inputs=[input_1, input_2], outputs=output_layer)
# Out:
# 2024-02-25 17:03:59.884835: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Define Contrastive Loss

# %%
def loss(margin=1):
    """Provides 'contrastive_loss' an enclosing scope with variable 'margin'.

    Arguments:
        margin: Integer, defines the baseline for distance for which pairs
                should be classified as dissimilar. - (default is 1).

    Returns:
        'contrastive_loss' function with data ('margin') attached.
    """

    # Contrastive loss = mean( (1-true_value) * square(prediction) +
    #                         true_value * square( max(margin-prediction, 0) ))
    def contrastive_loss(y_true, y_pred):
        """Calculates the contrastive loss.

        Arguments:
            y_true: List of labels, each label is of type float32.
            y_pred: List of predictions of same length as of y_true,
                    each label is of type float32.

        Returns:
            A tensor containing contrastive loss as floating point value.
        """

        square_pred = K.square(y_pred)
        margin_square = K.square(K.maximum(margin - (y_pred), 0))
        return K.mean((1 - y_true) * square_pred + (y_true) * margin_square)

    return contrastive_loss

# %% [markdown]
# # Compile the model with the contrastive loss

# %%
siamese.compile(loss=loss(margin=margin), optimizer="RMSprop", metrics=["accuracy"])
siamese.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  input_3 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  model (Functional)             (None, 10)           39590       ['input_2[0][0]',
#                                                                   'input_3[0][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['model[0][0]',
#                                                                   'model[1][0]']
#
#  batch_normalization_2 (BatchNo  (None, 1)           4           ['lambda[0][0]']
#  rmalization)
#
#  dense_1 (Dense)                (None, 1)            2           ['batch_normalization_2[0][0]']
#
# ==================================================================================================
# Total params: 39,596
# Trainable params: 34,184
# Non-trainable params: 5,412
# __________________________________________________________________________________________________

# %%
history = siamese.fit(
    [x_train_1, x_train_2],
    labels_train,
    validation_data=([x_val_1, x_val_2], labels_val),
    batch_size=batch_size,
    epochs=150,
)
# Out:
# Epoch 1/150
# 20/20 [==============================] - 3s 78ms/step - loss: 0.1943 - accuracy: 0.7844 - val_loss: 0.2486 - val_accuracy: 0.5000
# Epoch 2/150
# 20/20 [==============================] - 1s 62ms/step - loss: 0.1677 - accuracy: 0.8813 - val_loss: 0.2522 - val_accuracy: 0.5000
# Epoch 3/150
# 20/20 [==============================] - 1s 58ms/step - loss: 0.1524 - accuracy: 0.9250 - val_loss: 0.2579 - val_accuracy: 0.5000
# Epoch 4/150
# 20/20 [==============================] - 1s 58ms/step - loss: 0.1417 - accuracy: 0.9781 - val_loss: 0.2586 - val_accuracy: 0.5000
# Epoch 5/150
# 20/20 [==============================] - 1s 59ms/step - loss: 0.1335 - accuracy: 0.9781 - val_loss: 0.2587 - val_accuracy: 0.5000
# Epoch 6/150
# 20/20 [==============================] - 1s 61ms/step - loss: 0.1288 - accuracy: 0.9656 - val_loss: 0.2535 - val_accuracy: 0.5000
# Epoch 7/150
# 20/20 [==============================] - 1s 63ms/step - loss: 0.1232 - accuracy: 0.9844 - val_loss: 0.2515 - val_accuracy: 0.5000
# Epoch 8/150
# 20/20 [==============================] - 1s 64ms/step - loss: 0.1170 - accuracy: 0.9844 - val_loss: 0.2372 - val_accuracy: 0.5000
# Epoch 9/150
# 20/20 [==============================] - 1s 66ms/step - loss: 0.1134 - accuracy: 0.9844 - val_loss: 0.2243 - val_accuracy: 0.5125
# Epoch 10/150
# 20/20 [==============================] - 1s 71ms/step - loss: 0.1067 - accuracy: 0.9969 - val_loss: 0.2084 - val_accuracy: 0.5625
# Epoch 11/150
# 20/20 [==============================] - 1s 70ms/step - loss: 0.1029 - accuracy: 1.0000 - val_loss: 0.1878 - val_accuracy: 0.6875
# Epoch 12/150
# 20/20 [==============================] - 1s 75ms/step - loss: 0.1013 - accuracy: 0.9844 - val_loss: 0.1709 - val_accuracy: 0.7656
# Epoch 13/150
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0888 - accuracy: 0.9937 - val_loss: 0.1590 - val_accuracy: 0.8125
# Epoch 14/150
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0840 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.8531
# Epoch 15/150
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0827 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.8750
# Epoch 16/150
# 20/20 [==============================] - 2s 82ms/step - loss: 0.0793 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 0.9125
# Epoch 17/150
# 20/20 [==============================] - 2s 81ms/step - loss: 0.0755 - accuracy: 1.0000 - val_loss: 0.1293 - val_accuracy: 0.8844
# Epoch 18/150
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0709 - accuracy: 0.9969 - val_loss: 0.1135 - val_accuracy: 0.9000
# Epoch 19/150
# 20/20 [==============================] - 2s 84ms/step - loss: 0.0696 - accuracy: 1.0000 - val_loss: 0.1063 - val_accuracy: 0.9156
# Epoch 20/150
# 20/20 [==============================] - 2s 82ms/step - loss: 0.0628 - accuracy: 0.9969 - val_loss: 0.0954 - val_accuracy: 0.9281
# Epoch 21/150
# 20/20 [==============================] - 2s 87ms/step - loss: 0.0655 - accuracy: 0.9969 - val_loss: 0.0970 - val_accuracy: 0.9281
# Epoch 22/150
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0566 - accuracy: 1.0000 - val_loss: 0.0994 - val_accuracy: 0.9125
# Epoch 23/150
# 20/20 [==============================] - 3s 138ms/step - loss: 0.0523 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 0.9219
# Epoch 24/150
# 20/20 [==============================] - 2s 110ms/step - loss: 0.0516 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 0.9219
# Epoch 25/150
# 20/20 [==============================] - 3s 138ms/step - loss: 0.0501 - accuracy: 0.9906 - val_loss: 0.0855 - val_accuracy: 0.9250
# Epoch 26/150
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0488 - accuracy: 0.9969 - val_loss: 0.0829 - val_accuracy: 0.9281
# Epoch 27/150
# 20/20 [==============================] - 3s 147ms/step - loss: 0.0486 - accuracy: 1.0000 - val_loss: 0.0879 - val_accuracy: 0.9094
# Epoch 28/150
# 20/20 [==============================] - 3s 138ms/step - loss: 0.0468 - accuracy: 0.9937 - val_loss: 0.0865 - val_accuracy: 0.8875
# Epoch 29/150
# 20/20 [==============================] - 4s 202ms/step - loss: 0.0390 - accuracy: 0.9937 - val_loss: 0.0824 - val_accuracy: 0.9094
# Epoch 30/150
# 20/20 [==============================] - 3s 163ms/step - loss: 0.0366 - accuracy: 1.0000 - val_loss: 0.0873 - val_accuracy: 0.9094
# Epoch 31/150
# 20/20 [==============================] - 4s 194ms/step - loss: 0.0330 - accuracy: 1.0000 - val_loss: 0.0784 - val_accuracy: 0.9094
# Epoch 32/150
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0308 - accuracy: 1.0000 - val_loss: 0.0757 - val_accuracy: 0.9250
# Epoch 33/150
# 20/20 [==============================] - 2s 114ms/step - loss: 0.0316 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9250
# Epoch 34/150
# 20/20 [==============================] - 2s 112ms/step - loss: 0.0251 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9250
# Epoch 35/150
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0260 - accuracy: 0.9969 - val_loss: 0.0720 - val_accuracy: 0.9281
# Epoch 36/150
# 20/20 [==============================] - 2s 123ms/step - loss: 0.0233 - accuracy: 0.9969 - val_loss: 0.0714 - val_accuracy: 0.9312
# Epoch 37/150
# 20/20 [==============================] - 3s 148ms/step - loss: 0.0236 - accuracy: 0.9969 - val_loss: 0.0723 - val_accuracy: 0.9156
# Epoch 38/150
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0240 - accuracy: 0.9969 - val_loss: 0.0735 - val_accuracy: 0.9125
# Epoch 39/150
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0182 - accuracy: 0.9969 - val_loss: 0.0640 - val_accuracy: 0.9344
# Epoch 40/150
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0232 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 0.9406
# Epoch 41/150
# 20/20 [==============================] - 2s 119ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.0623 - val_accuracy: 0.9281
# Epoch 42/150
# 20/20 [==============================] - 2s 108ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.0774 - val_accuracy: 0.9062
# Epoch 43/150
# 20/20 [==============================] - 3s 132ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.0706 - val_accuracy: 0.9094
# Epoch 44/150
# 20/20 [==============================] - 2s 114ms/step - loss: 0.0178 - accuracy: 0.9969 - val_loss: 0.0623 - val_accuracy: 0.9219
# Epoch 45/150
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.0677 - val_accuracy: 0.9125
# Epoch 46/150
# 20/20 [==============================] - 2s 112ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0678 - val_accuracy: 0.9187
# Epoch 47/150
# 20/20 [==============================] - 2s 116ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9281
# Epoch 48/150
# 20/20 [==============================] - 2s 102ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0677 - val_accuracy: 0.9156
# Epoch 49/150
# 20/20 [==============================] - 3s 135ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9281
# Epoch 50/150
# 20/20 [==============================] - 3s 133ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0615 - val_accuracy: 0.9375
# Epoch 51/150
# 20/20 [==============================] - 3s 138ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.0535 - val_accuracy: 0.9438
# Epoch 52/150
# 20/20 [==============================] - 3s 144ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0632 - val_accuracy: 0.9250
# Epoch 53/150
# 20/20 [==============================] - 3s 136ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0569 - val_accuracy: 0.9312
# Epoch 54/150
# 20/20 [==============================] - 3s 144ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 0.9219
# Epoch 55/150
# 20/20 [==============================] - 3s 142ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.0606 - val_accuracy: 0.9281
# Epoch 56/150
# 20/20 [==============================] - 2s 122ms/step - loss: 0.0072 - accuracy: 0.9969 - val_loss: 0.0686 - val_accuracy: 0.9125
# Epoch 57/150
# 20/20 [==============================] - 3s 132ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0574 - val_accuracy: 0.9406
# Epoch 58/150
# 20/20 [==============================] - 2s 107ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0515 - val_accuracy: 0.9406
# Epoch 59/150
# 20/20 [==============================] - 2s 116ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0553 - val_accuracy: 0.9406
# Epoch 60/150
# 20/20 [==============================] - 3s 128ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0560 - val_accuracy: 0.9125
# Epoch 61/150
# 20/20 [==============================] - 2s 124ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0522 - val_accuracy: 0.9344
# Epoch 62/150
# 20/20 [==============================] - 2s 116ms/step - loss: 0.0076 - accuracy: 0.9969 - val_loss: 0.0577 - val_accuracy: 0.9375
# Epoch 63/150
# 20/20 [==============================] - 2s 114ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0574 - val_accuracy: 0.9281
# Epoch 64/150
# 20/20 [==============================] - 3s 133ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0573 - val_accuracy: 0.9156
# Epoch 65/150
# 20/20 [==============================] - 2s 124ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0581 - val_accuracy: 0.9375
# Epoch 66/150
# 20/20 [==============================] - 2s 112ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0518 - val_accuracy: 0.9438
# Epoch 67/150
# 20/20 [==============================] - 2s 114ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0581 - val_accuracy: 0.9250
# Epoch 68/150
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0625 - val_accuracy: 0.9125
# Epoch 69/150
# 20/20 [==============================] - 3s 133ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0586 - val_accuracy: 0.9187
# Epoch 70/150
# 20/20 [==============================] - 3s 134ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0544 - val_accuracy: 0.9250
# Epoch 71/150
# 20/20 [==============================] - 2s 123ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0566 - val_accuracy: 0.9250
# Epoch 72/150
# 20/20 [==============================] - 2s 115ms/step - loss: 0.0076 - accuracy: 0.9937 - val_loss: 0.0657 - val_accuracy: 0.8813
# Epoch 73/150
# 20/20 [==============================] - 2s 116ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0587 - val_accuracy: 0.9156
# Epoch 74/150
# 20/20 [==============================] - 3s 131ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0697 - val_accuracy: 0.9094
# Epoch 75/150
# 20/20 [==============================] - 2s 109ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0566 - val_accuracy: 0.9187
# Epoch 76/150
# 20/20 [==============================] - 2s 102ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0625 - val_accuracy: 0.9031
# Epoch 77/150
# 20/20 [==============================] - 2s 105ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0687 - val_accuracy: 0.9156
# Epoch 78/150
# 20/20 [==============================] - 2s 110ms/step - loss: 0.0037 - accuracy: 0.9969 - val_loss: 0.0499 - val_accuracy: 0.9312
# Epoch 79/150
# 20/20 [==============================] - 2s 109ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0548 - val_accuracy: 0.9187
# Epoch 80/150
# 20/20 [==============================] - 2s 104ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0495 - val_accuracy: 0.9281
# Epoch 81/150
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0045 - accuracy: 0.9969 - val_loss: 0.0519 - val_accuracy: 0.9219
# Epoch 82/150
# 20/20 [==============================] - 2s 105ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0525 - val_accuracy: 0.9281
# Epoch 83/150
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0633 - val_accuracy: 0.9187
# Epoch 84/150
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 0.9187
# Epoch 85/150
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0545 - val_accuracy: 0.9281
# Epoch 86/150
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9062
# Epoch 87/150
# 20/20 [==============================] - 2s 97ms/step - loss: 6.5120e-04 - accuracy: 1.0000 - val_loss: 0.0546 - val_accuracy: 0.9250
# Epoch 88/150
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0467 - val_accuracy: 0.9281
# Epoch 89/150
# 20/20 [==============================] - 2s 96ms/step - loss: 8.4947e-04 - accuracy: 1.0000 - val_loss: 0.0496 - val_accuracy: 0.9250
# Epoch 90/150
# 20/20 [==============================] - 2s 98ms/step - loss: 6.9032e-04 - accuracy: 1.0000 - val_loss: 0.0577 - val_accuracy: 0.9250
# Epoch 91/150
# 20/20 [==============================] - 2s 97ms/step - loss: 4.6576e-04 - accuracy: 1.0000 - val_loss: 0.0486 - val_accuracy: 0.9281
# Epoch 92/150
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0553 - val_accuracy: 0.9219
# Epoch 93/150
# 20/20 [==============================] - 2s 114ms/step - loss: 2.5713e-04 - accuracy: 1.0000 - val_loss: 0.0576 - val_accuracy: 0.9250
# Epoch 94/150
# 20/20 [==============================] - 2s 105ms/step - loss: 0.0028 - accuracy: 0.9969 - val_loss: 0.0501 - val_accuracy: 0.9344
# Epoch 95/150
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0021 - accuracy: 0.9969 - val_loss: 0.0503 - val_accuracy: 0.9250
# Epoch 96/150
# 20/20 [==============================] - 2s 105ms/step - loss: 0.0047 - accuracy: 0.9937 - val_loss: 0.0503 - val_accuracy: 0.9250
# Epoch 97/150
# 20/20 [==============================] - 2s 113ms/step - loss: 0.0026 - accuracy: 0.9969 - val_loss: 0.0465 - val_accuracy: 0.9312
# Epoch 98/150
# 20/20 [==============================] - 2s 106ms/step - loss: 6.4664e-04 - accuracy: 1.0000 - val_loss: 0.0539 - val_accuracy: 0.9281
# Epoch 99/150
# 20/20 [==============================] - 2s 109ms/step - loss: 7.6498e-04 - accuracy: 1.0000 - val_loss: 0.0480 - val_accuracy: 0.9344
# Epoch 100/150
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0567 - val_accuracy: 0.9156
# Epoch 101/150
# 20/20 [==============================] - 2s 104ms/step - loss: 5.4798e-04 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9031
# Epoch 102/150
# 20/20 [==============================] - 2s 110ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0550 - val_accuracy: 0.9125
# Epoch 103/150
# 20/20 [==============================] - 2s 116ms/step - loss: 0.0054 - accuracy: 0.9906 - val_loss: 0.0463 - val_accuracy: 0.9438
# Epoch 104/150
# 20/20 [==============================] - 2s 114ms/step - loss: 6.7108e-04 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 0.9375
# Epoch 105/150
# 20/20 [==============================] - 2s 119ms/step - loss: 0.0020 - accuracy: 0.9969 - val_loss: 0.0558 - val_accuracy: 0.9219
# Epoch 106/150
# 20/20 [==============================] - 2s 116ms/step - loss: 0.0045 - accuracy: 0.9937 - val_loss: 0.0359 - val_accuracy: 0.9531
# Epoch 107/150
# 20/20 [==============================] - 2s 115ms/step - loss: 0.0123 - accuracy: 0.9875 - val_loss: 0.0606 - val_accuracy: 0.9281
# Epoch 108/150
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0469 - val_accuracy: 0.9375
# Epoch 109/150
# 20/20 [==============================] - 2s 110ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0487 - val_accuracy: 0.9344
# Epoch 110/150
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0033 - accuracy: 0.9969 - val_loss: 0.0582 - val_accuracy: 0.9281
# Epoch 111/150
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0538 - val_accuracy: 0.9312
# Epoch 112/150
# 20/20 [==============================] - 2s 103ms/step - loss: 6.2640e-04 - accuracy: 1.0000 - val_loss: 0.0572 - val_accuracy: 0.9312
# Epoch 113/150
# 20/20 [==============================] - 2s 104ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0480 - val_accuracy: 0.9344
# Epoch 114/150
# 20/20 [==============================] - 2s 103ms/step - loss: 4.4702e-04 - accuracy: 1.0000 - val_loss: 0.0822 - val_accuracy: 0.8938
# Epoch 115/150
# 20/20 [==============================] - 2s 102ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0706 - val_accuracy: 0.9094
# Epoch 116/150
# 20/20 [==============================] - 2s 104ms/step - loss: 0.0037 - accuracy: 0.9969 - val_loss: 0.0465 - val_accuracy: 0.9187
# Epoch 117/150
# 20/20 [==============================] - 2s 107ms/step - loss: 4.1200e-04 - accuracy: 1.0000 - val_loss: 0.0564 - val_accuracy: 0.9281
# Epoch 118/150
# 20/20 [==============================] - 2s 109ms/step - loss: 5.3314e-04 - accuracy: 1.0000 - val_loss: 0.0488 - val_accuracy: 0.9375
# Epoch 119/150
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0033 - accuracy: 0.9969 - val_loss: 0.0458 - val_accuracy: 0.9375
# Epoch 120/150
# 20/20 [==============================] - 2s 104ms/step - loss: 1.9517e-04 - accuracy: 1.0000 - val_loss: 0.0532 - val_accuracy: 0.9281
# Epoch 121/150
# 20/20 [==============================] - 2s 99ms/step - loss: 2.7997e-04 - accuracy: 1.0000 - val_loss: 0.0558 - val_accuracy: 0.9219
# Epoch 122/150
# 20/20 [==============================] - 2s 112ms/step - loss: 4.9976e-04 - accuracy: 1.0000 - val_loss: 0.0463 - val_accuracy: 0.9312
# Epoch 123/150
# 20/20 [==============================] - 2s 106ms/step - loss: 0.0053 - accuracy: 0.9906 - val_loss: 0.0477 - val_accuracy: 0.9344
# Epoch 124/150
# 20/20 [==============================] - 2s 109ms/step - loss: 3.6262e-04 - accuracy: 1.0000 - val_loss: 0.0479 - val_accuracy: 0.9375
# Epoch 125/150
# 20/20 [==============================] - 2s 104ms/step - loss: 4.2806e-04 - accuracy: 1.0000 - val_loss: 0.0538 - val_accuracy: 0.9281
# Epoch 126/150
# 20/20 [==============================] - 2s 99ms/step - loss: 7.0331e-04 - accuracy: 1.0000 - val_loss: 0.0608 - val_accuracy: 0.9250
# Epoch 127/150
# 20/20 [==============================] - 2s 104ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0557 - val_accuracy: 0.9344
# Epoch 128/150
# 20/20 [==============================] - 2s 99ms/step - loss: 7.0347e-04 - accuracy: 1.0000 - val_loss: 0.0555 - val_accuracy: 0.9344
# Epoch 129/150
# 20/20 [==============================] - 2s 106ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0485 - val_accuracy: 0.9344
# Epoch 130/150
# 20/20 [==============================] - 2s 100ms/step - loss: 7.9704e-04 - accuracy: 1.0000 - val_loss: 0.0540 - val_accuracy: 0.9219
# Epoch 131/150
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0507 - val_accuracy: 0.9250
# Epoch 132/150
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0039 - accuracy: 0.9969 - val_loss: 0.0482 - val_accuracy: 0.9438
# Epoch 133/150
# 20/20 [==============================] - 2s 103ms/step - loss: 0.0038 - accuracy: 0.9937 - val_loss: 0.0489 - val_accuracy: 0.9312
# Epoch 134/150
# 20/20 [==============================] - 2s 98ms/step - loss: 4.9512e-04 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9438
# Epoch 135/150
# 20/20 [==============================] - 2s 102ms/step - loss: 5.4997e-05 - accuracy: 1.0000 - val_loss: 0.0456 - val_accuracy: 0.9406
# Epoch 136/150
# 20/20 [==============================] - 2s 102ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0537 - val_accuracy: 0.9281
# Epoch 137/150
# 20/20 [==============================] - 2s 102ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0623 - val_accuracy: 0.9250
# Epoch 138/150
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0038 - accuracy: 0.9969 - val_loss: 0.0647 - val_accuracy: 0.9187
# Epoch 139/150
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0112 - accuracy: 0.9875 - val_loss: 0.0480 - val_accuracy: 0.9312
# Epoch 140/150
# 20/20 [==============================] - 2s 100ms/step - loss: 7.4796e-04 - accuracy: 1.0000 - val_loss: 0.0481 - val_accuracy: 0.9312
# Epoch 141/150
# 20/20 [==============================] - 2s 97ms/step - loss: 4.5350e-04 - accuracy: 1.0000 - val_loss: 0.0492 - val_accuracy: 0.9344
# Epoch 142/150
# 20/20 [==============================] - 2s 99ms/step - loss: 9.7635e-04 - accuracy: 0.9969 - val_loss: 0.0613 - val_accuracy: 0.9187
# Epoch 143/150
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0707 - val_accuracy: 0.9062
# Epoch 144/150
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0021 - accuracy: 0.9969 - val_loss: 0.0612 - val_accuracy: 0.9156
# Epoch 145/150
# 20/20 [==============================] - 2s 102ms/step - loss: 0.0018 - accuracy: 0.9969 - val_loss: 0.0589 - val_accuracy: 0.9187
# Epoch 146/150
# 20/20 [==============================] - 2s 102ms/step - loss: 5.4433e-05 - accuracy: 1.0000 - val_loss: 0.0564 - val_accuracy: 0.9250
# Epoch 147/150
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0042 - accuracy: 0.9969 - val_loss: 0.0384 - val_accuracy: 0.9500
# Epoch 148/150
# 20/20 [==============================] - 2s 98ms/step - loss: 2.2459e-04 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 0.9406
# Epoch 149/150
# 20/20 [==============================] - 2s 95ms/step - loss: 1.8357e-04 - accuracy: 1.0000 - val_loss: 0.0471 - val_accuracy: 0.9375
# Epoch 150/150
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0018 - accuracy: 0.9969 - val_loss: 0.0423 - val_accuracy: 0.9375

# %%
def plt_metric(history, metric, title, has_valid=True):
    """Plots the given 'metric' from 'history'.

    Arguments:
        history: history attribute of History object returned from Model.fit.
        metric: Metric to plot, a string value present as key in 'history'.
        title: A string to be used as title of plot.
        has_valid: Boolean, true if valid data was passed to Model.fit else false.

    Returns:
        None.
    """
    plt.plot(history[metric])
    if has_valid:
        plt.plot(history["val_" + metric])
        plt.legend(["train", "validation"], loc="upper left")
    plt.title(title)
    plt.ylabel(metric)
    plt.xlabel("epoch")
    plt.savefig('../images/firstmodel')
    plt.show()


# Plot the accuracy
plt_metric(history=history.history, metric="accuracy", title="Model accuracy")

# Plot the contrastive loss
plt_metric(history=history.history, metric="loss", title="Contrastive Loss")

# %%
# Training Plot
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.legend(["Loss", "Validation Loss", "Accuracy", "Validation Accuracy"])
plt.savefig('../images/model_acc_loss')

# %%
results = siamese.evaluate([x_test_1, x_test_2], labels_test)
print("test loss, test acc:", results)
# Out:
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0400 - accuracy: 0.9375
# test loss, test acc: [0.03998460993170738, 0.9375]

# %%
predictions = siamese.predict([x_test_1, x_test_2])
visualize(pairs_test, labels_test, to_show=3, predictions=predictions, test=True)
# Out:
# 5/5 [==============================] - 0s 15ms/step

# %%
print(predictions)
# Out:
# [[5.6922740e-06]
#  [6.5744519e-01]
#  [3.7152230e-04]
#  [9.9985200e-01]
#  [8.1309460e-02]
#  [8.8724273e-01]
#  [5.6922740e-06]
#  [9.6767879e-01]
#  [5.2680358e-02]
#  [9.5380372e-01]
#  [5.6922740e-06]
#  [9.9752253e-01]
#  [5.6922740e-06]
#  [9.9597394e-01]
#  [5.2680358e-02]
#  [9.4093537e-01]
#  [1.2300210e-01]
#  [8.9856541e-01]
#  [3.6669753e-02]
#  [8.9856541e-01]
#  [5.6922740e-06]
#  [9.9997991e-01]
#  [5.6922740e-06]
#  [9.9997717e-01]
#  [7.8907758e-02]
#  [9.9998367e-01]
#  [1.2773474e-02]
#  [9.9998647e-01]
#  [5.6922740e-06]
#  [8.0950772e-03]
#  [9.4212897e-02]
#  [1.3968135e-01]
#  [9.0293095e-02]
#  [9.5215625e-01]
#  [7.7764352e-04]
#  [6.0775983e-01]
#  [5.6922740e-06]
#  [9.9988449e-01]
#  [1.2518378e-01]
#  [2.9104647e-01]
#  [2.1461330e-03]
#  [9.9970818e-01]
#  [5.6922740e-06]
#  [9.9986851e-01]
#  [5.6101237e-03]
#  [2.9358298e-01]
#  [5.6922740e-06]
#  [8.2051849e-01]
#  [5.6922740e-06]
#  [9.9999589e-01]
#  [5.6922740e-06]
#  [9.8138219e-01]
#  [5.6922740e-06]
#  [9.9996907e-01]
#  [6.7212863e-04]
#  [9.9307257e-01]
#  [1.6390327e-02]
#  [9.9723434e-01]
#  [5.6922740e-06]
#  [9.9893588e-01]
#  [7.5560594e-01]
#  [9.2527217e-01]
#  [5.6922740e-06]
#  [9.9976802e-01]
#  [2.3506484e-03]
#  [9.9676406e-01]
#  [7.8907758e-02]
#  [9.9996042e-01]
#  [5.6922740e-06]
#  [9.9966091e-01]
#  [5.6922740e-06]
#  [9.8628771e-01]
#  [5.6922740e-06]
#  [2.0602885e-01]
#  [5.6922740e-06]
#  [6.0140240e-01]
#  [5.6922740e-06]
#  [9.9813002e-01]
#  [1.1835300e-03]
#  [9.9982536e-01]
#  [1.3636404e-01]
#  [9.9930394e-01]
#  [3.8028453e-02]
#  [9.9999887e-01]
#  [5.0284070e-01]
#  [9.9947351e-01]
#  [5.6922740e-06]
#  [9.8092383e-01]
#  [5.6922740e-06]
#  [9.5057398e-01]
#  [3.0583033e-02]
#  [9.9871379e-01]
#  [5.6922740e-06]
#  [9.8191530e-01]
#  [5.6922740e-06]
#  [4.1484559e-01]
#  [5.6922740e-06]
#  [9.9946928e-01]
#  [5.5693999e-02]
#  [8.4344774e-01]
#  [5.6922740e-06]
#  [9.9508512e-01]
#  [5.6922740e-06]
#  [9.9999154e-01]
#  [5.6922740e-06]
#  [9.5785695e-01]
#  [5.6922740e-06]
#  [3.1185627e-01]
#  [7.7764352e-04]
#  [9.7573191e-01]
#  [5.6922740e-06]
#  [9.9138659e-01]
#  [6.7212863e-04]
#  [9.4092536e-01]
#  [3.4918327e-02]
#  [9.9990779e-01]
#  [5.6922740e-06]
#  [9.9753308e-01]
#  [9.1527574e-02]
#  [9.9076277e-01]
#  [3.6669753e-02]
#  [9.9963790e-01]
#  [5.6922740e-06]
#  [9.9842483e-01]
#  [5.6922740e-06]
#  [9.9962676e-01]
#  [3.2009372e-01]
#  [9.9993670e-01]
#  [1.5549735e-02]
#  [1.0000000e+00]
#  [8.1309460e-02]
#  [9.7653484e-01]
#  [5.6922740e-06]
#  [9.6333808e-01]
#  [5.6922740e-06]
#  [6.2660545e-01]
#  [4.3752053e-01]
#  [9.6252269e-01]
#  [5.6922740e-06]
#  [9.9985808e-01]
#  [5.6922740e-06]
#  [9.7093183e-01]
#  [5.6922740e-06]
#  [9.6904182e-01]
#  [1.3629615e-02]
#  [9.9988383e-01]
#  [5.4070598e-01]
#  [9.9990761e-01]
#  [5.6922740e-06]
#  [9.9963278e-01]
#  [5.6922740e-06]
#  [9.9999624e-01]
#  [3.1179254e-04]
#  [9.9358445e-01]
#  [4.6238314e-02]
#  [9.9997950e-01]
#  [3.4918327e-02]
#  [9.9923790e-01]
#  [3.7152230e-04]
#  [9.1749543e-01]]

# %% [markdown]
# Next steps.
#
# - save the model
# - data collection
# - train the model on cohorts faces
# - implement transfer learning
