# %% [markdown]
# # **Face Recognition**
#
#
# **Project Overview**
#
# This project addresses the escalating demand for sophisticated and precise facial recognition systems across diverse domains, including security, attendance management, and user authentication. Leveraging advancements in deep learning techniques, the focus is on elevating the performance of these systems through the implementation of a custom Siamese neural network—a potent architecture renowned for its efficacy in face recognition tasks.
#
# **Data Analysis**
#
# The training dataset utilized for the custom Siamese neural network comprises images of classmates, ensuring diversity in facial expressions, lighting conditions, and angles. This diversity aims to fortify the model's resilience and adaptability in real-world scenarios.
#
# **Data Preprocessing**
#
# To prepare the dataset for training, a comprehensive data preprocessing pipeline was employed. This included resizing, normalization, and other essential transformations performed through a dedicated function to enhance the quality and suitability of the input images.
#
# **Model Development**
#
# The core of the project involved implementing a Siamese neural network, consisting of two identical convolutional neural networks running concurrently. This architecture effectively treats the system as a singular neural network with dual inputs. To optimize the learning process, a custom loss function was devised, leveraging the contrastive loss algorithm.
#
# **Model Evaluation**
#
# The performance evaluation of the model revealed exceptional results, showcasing a remarkable accuracy of 99% on the test set and a perfect 100% accuracy on the training set. Further insights into the model's training progress, including loss and accuracy metrics, are visually represented in the plotted graphs at the conclusion of the notebook.
#
# This project not only contributes to the advancement of facial recognition systems but also underscores the efficacy of the custom Siamese neural network architecture in achieving robust and accurate results.

# %% [markdown]
# # Setup and Import Dependencies

# %%
import random
import numpy as np
import keras
from keras import backend as K
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import cv2
import os
import tensorflow as tf
import random
import pickle
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %% [markdown]
# # Hyperparameters

# %%
epochs = 10
batch_size = 16
margin = 1  # Margin for contrastive loss.

# %% [markdown]
# # Initialize Data Folder

# %%
data_folder = '/content/drive/MyDrive/flatiron/cohort_faces/'

# %% [markdown]
# - Preprocess the image
# - Visualize the images
# - Create image pairs
# - Load the model
# - Predict on new dataset

# %% [markdown]
# # Helper Functions
# - Preprocessing function
# - visualization functions
# - create image pairs function

# %%
# without cropping faces preprocessing function
def preprocess_image(image_path, target_size=(256,256)):
    """Preprocesses the given image.

    Arguments:
        image_path: The path to the image file.
        target_size: A tuple of integers indicating the target size.

    Returns:
        A preprocessed image.
    """
    # Step 1: Load the image
    image = cv2.imread(image_path)

    # Step 2: Check if the image was loaded successfully
    if image is None:
        print("Failed to load image:", image_path)
        return None

    # Step 3: Convert image to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Step 4: Resize the grayscale image
    resized_image = cv2.resize(gray_image, target_size)

    # Step 5: Normalize pixel values
    normalized_image = resized_image / 255.0

    return normalized_image

# %%
def preprocess_image(image_path, target_size=(256,256), crop_faces=True):
    """Preprocesses the given image.

    Arguments:
        image_path: The path to the image file.
        target_size: A tuple of integers indicating the target size.
        crop_faces: A boolean indicating whether to crop faces from the image.

    Returns:
        A preprocessed image.
    """
    # Step 1: Load the image
    image = cv2.imread(image_path)

    # Step 2: Check if the image was loaded successfully
    if image is None:
        print("Failed to load image:", image_path)
        return None

    # Step 3: Convert image to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Step 4: Crop faces from the image if enabled
    if crop_faces:
        cascPath = '/content/drive/MyDrive/flatiron/haarcascade_frontalface_default.xml'
        faceCascade = cv2.CascadeClassifier(cascPath)
        faces = faceCascade.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=5, minSize=(15,15))
        if len(faces) > 0:
            (x, y, w, h) = faces[0]
            gray_image = gray_image[y:y+h, x:x+w]

    # Step 5: Resize the grayscale image
    resized_image = cv2.resize(gray_image, target_size)

    # Step 6: Normalize pixel values
    normalized_image = resized_image / 255.0

    return normalized_image

# %%
def visualize_normalized_image(image):
    # Reshape the flattened image to its original shape
    target_shape = (256,256)  # Replace with the actual target size
    reshaped_image = np.reshape(image, target_shape)

    # Display the normalized image
    plt.imshow(reshaped_image, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
def visualize(pairs, labels, to_show=6, num_col=3, predictions=None, test=False):
    """Creates a plot of pairs and labels, and prediction if it's test dataset.

    Arguments:
        pairs: Numpy Array, of pairs to visualize, having shape
               (Number of pairs, 2, 28, 28).
        to_show: Int, number of examples to visualize (default is 6)
                `to_show` must be an integral multiple of `num_col`.
                 Otherwise it will be trimmed if it is greater than num_col,
                 and incremented if if it is less then num_col.
        num_col: Int, number of images in one row - (default is 3)
                 For test and train respectively, it should not exceed 3 and 7.
        predictions: Numpy Array of predictions with shape (to_show, 1) -
                     (default is None)
                     Must be passed when test=True.
        test: Boolean telling whether the dataset being visualized is
              train dataset or test dataset - (default False).

    Returns:
        None.
    """

    # Define num_row
    # If to_show % num_col != 0
    #    trim to_show,
    #       to trim to_show limit num_row to the point where
    #       to_show % num_col == 0
    #
    # If to_show//num_col == 0
    #    then it means num_col is greater then to_show
    #    increment to_show
    #       to increment to_show set num_row to 1
    num_row = to_show // num_col if to_show // num_col != 0 else 1

    # `to_show` must be an integral multiple of `num_col`
    #  we found num_row and we have num_col
    #  to increment or decrement to_show
    #  to make it integral multiple of `num_col`
    #  simply set it equal to num_row * num_col
    to_show = num_row * num_col

    # Plot the images
    fig, axes = plt.subplots(num_row, num_col, figsize=(5, 5))
    for i in range(to_show):
        # If the number of rows is 1, the axes array is one-dimensional
        if num_row == 1:
            ax = axes[i % num_col]
        else:
            ax = axes[i // num_col, i % num_col]

                        # Ensure the pairs are properly formatted
        pair_to_show = np.concatenate([pairs[i][0], pairs[i][1]], axis=0)

        ax.imshow(pair_to_show, cmap="gray")

        ax.set_axis_off()
        if test:
            ax.set_title("True: {} | Pred: {:.5f}".format(labels[i], predictions[i][0]))
        else:
            ax.set_title("Label: {}".format(labels[i]))
    if test:
        plt.tight_layout(rect=(0, 0, 1.9, 1.9), w_pad=0.0)
    else:
        plt.tight_layout(rect=(0, 0, 1.5, 1.5))
    plt.show()

# %% [markdown]
# # Create Image Pairs

# %%
def create_image_pairs(data_folder, max_pairs_per_person=45):
    person_folders = os.listdir(data_folder)
    image_pairs = []
    labels = []
    total_pairs_created = 0

    # Create an index of image files for each person
    person_images = {}
    for person_folder in person_folders:
        person_path = os.path.join(data_folder, person_folder)
        if not os.path.isdir(person_path):
            continue
        person_images[person_folder] = os.listdir(person_path)

    # Iterate through each person folder
    for person_folder in person_images:
        person_image_files = person_images[person_folder]
        pairs_created_for_person = 0

        # Create positive pairs within the same person folder
        for i in range(len(person_image_files)-1):
            for j in range(i+1, len(person_image_files)):
                if pairs_created_for_person >= max_pairs_per_person:
                    break

                image1_path = os.path.join(data_folder, person_folder, person_image_files[i])
                image2_path = os.path.join(data_folder, person_folder, person_image_files[j])
                preprocessed_image1 = preprocess_image(image1_path)
                preprocessed_image2 = preprocess_image(image2_path)
                if preprocessed_image1 is not None and preprocessed_image2 is not None:
                    image_pairs.append((preprocessed_image1, preprocessed_image2))
                    labels.append(0.0)  # Positive label
                    total_pairs_created += 1
                    pairs_created_for_person += 1

        # Create negative pairs with other person folders
        other_person_folders = [p for p in person_images if p != person_folder]
        for other_person_folder in other_person_folders:
            other_image_files = person_images[other_person_folder]

            for i in range(len(person_image_files)):
                for j in range(len(other_image_files)):
                    if pairs_created_for_person >= max_pairs_per_person:
                        break

                    image1_path = os.path.join(data_folder, person_folder, person_image_files[i])
                    image2_path = os.path.join(data_folder, other_person_folder, other_image_files[j])
                    preprocessed_image1 = preprocess_image(image1_path)
                    preprocessed_image2 = preprocess_image(image2_path)
                    if preprocessed_image1 is not None and preprocessed_image2 is not None:
                        image_pairs.append((preprocessed_image1, preprocessed_image2))
                        labels.append(1.0)  # Negative label
                        total_pairs_created += 1
                        pairs_created_for_person += 1

        print(f"Processed folder: {person_folder}, Pairs created: {pairs_created_for_person}/{max_pairs_per_person}")

    combined = list(zip(image_pairs, labels))
    random.shuffle(combined)
    image_pairs, labels = zip(*combined)

    return image_pairs, labels

# %%
data = create_image_pairs(data_folder)
# Out:
# Processed folder: Ronnie, Pairs created: 45/45
# Processed folder: Juan, Pairs created: 45/45
# Processed folder: Julie, Pairs created: 45/45
# Processed folder: Colby, Pairs created: 45/45
# Processed folder: Praveen, Pairs created: 45/45
# Processed folder: Sunny, Pairs created: 45/45
# Processed folder: Noah, Pairs created: 45/45
# Processed folder: John, Pairs created: 45/45
# Processed folder: Wesley, Pairs created: 45/45
# Processed folder: Ryan, Pairs created: 45/45
# Processed folder: Nechama, Pairs created: 45/45

# %% [markdown]
# # Save data in a pickle file
#
# so i can load it back in and wont have to run this function again.

# %%
pickle.dump(data, open('/content/drive/MyDrive/flatiron/data.pkl', 'wb'))

# %%
data = pickle.load(open('/content/drive/MyDrive/flatiron/data.pkl', 'rb'))

# %%
image_pairs, labels = data

# %%
len(image_pairs)
# Out:
# 495

# %%
visualize(image_pairs[5:10], labels[5:10], to_show=4, num_col=4)

# %% [markdown]
# # Train Test Split

# %%
# Convert image_pairs and labels to NumPy arrays
image_pairs = np.array(image_pairs)
labels = np.array(labels)

# Split the data into training and testing sets
x_train_val, x_test, y_train_val, y_test = train_test_split(image_pairs, labels, test_size=0.2, random_state=42)

# Change the data type to a floating point format
x_train_val = x_train_val.astype("float32")
x_test = x_test.astype("float32")

# %%
len(x_train_val)
# Out:
# 396

# %%
# Keep 50% of train_val  in validation set
x_train, x_val = x_train_val[:247], x_train_val[247:]
y_train, y_val = y_train_val[:247], y_train_val[247:]
del x_train_val, y_train_val

# %%
x_train_1 = x_train[:, 0]  # x_train_1.shape is (18, 256, 256)
x_train_2 = x_train[:, 1]

x_val_1 = x_val[:, 0]  # x_val_1.shape = (18, 256, 256)
x_val_2 = x_val[:, 1]

x_test_1 = x_test[:, 0]  # x_test_1.shape = (9, 256, 256)
x_test_2 = x_test[:, 1]

# %%
x_test_1.shape
# Out:
# (99, 256, 256)

# %%
x_train_1.shape
# Out:
# (247, 256, 256)

# %%
x_val_1.shape
# Out:
# (149, 256, 256)

# %% [markdown]
# # Define Model

# %%
@keras.saving.register_keras_serializable()
# Provided two tensors t1 and t2
# Euclidean distance = sqrt(sum(square(t1-t2)))
def euclidean_distance(vects):
    """Find the Euclidean distance between two vectors.


    Arguments:
        vects: List containing two tensors of same length.

    Returns:
        Tensor containing euclidean distance
        (as floating point value) between vectors.
    """

    x, y = vects
    sum_square = K.sum(K.square(x - y), axis=1, keepdims=True)
    return K.sqrt(K.maximum(sum_square, K.epsilon()))


input = keras.layers.Input((256, 256, 1))
x = keras.layers.BatchNormalization()(input)
x = keras.layers.Conv2D(4, (5, 5), activation="relu")(x)
x = keras.layers.AveragePooling2D(pool_size=(2, 2))(x)
x = keras.layers.Conv2D(16, (5, 5), activation="relu")(x)
x = keras.layers.AveragePooling2D(pool_size=(2, 2))(x)
x = keras.layers.Flatten()(x)

x = keras.layers.BatchNormalization()(x)
x = keras.layers.Dense(10, activation="relu")(x)
embedding_network = keras.Model(input, x)


input_1 = keras.layers.Input((256, 256, 1))
input_2 = keras.layers.Input((256, 256, 1))

# As mentioned above, Siamese Network share weights between
# tower networks (sister networks). To allow this, we will use
# same embedding network for both tower networks.
tower_1 = embedding_network(input_1)
tower_2 = embedding_network(input_2)

merge_layer = keras.layers.Lambda(euclidean_distance, output_shape=(1,))(
    [tower_1, tower_2]
)
normal_layer = keras.layers.BatchNormalization()(merge_layer)
output_layer = keras.layers.Dense(1, activation="sigmoid")(normal_layer)
siamese = keras.Model(inputs=[input_1, input_2], outputs=output_layer)

# %% [markdown]
# # Define Contrastive Loss

# %%
@keras.saving.register_keras_serializable()
def loss(margin=1):
    """Provides 'contrastive_loss' an enclosing scope with variable 'margin'.

    Arguments:
        margin: Integer, defines the baseline for distance for which pairs
                should be classified as dissimilar. - (default is 1).

    Returns:
        'contrastive_loss' function with data ('margin') attached.
    """

    # Contrastive loss = mean( (1-true_value) * square(prediction) +
    #                         true_value * square( max(margin-prediction, 0) ))
    @keras.saving.register_keras_serializable()
    def contrastive_loss(y_true, y_pred):
        """Calculates the contrastive loss.

        Arguments:
            y_true: List of labels, each label is of type float32.
            y_pred: List of predictions of same length as of y_true,
                    each label is of type float32.

        Returns:
            A tensor containing contrastive loss as floating point value.
        """

        square_pred = K.square(y_pred)
        margin_square = K.square(K.maximum(margin - (y_pred), 0))
        return K.mean((1 - y_true) * square_pred + (y_true) * margin_square)

    return contrastive_loss

# %% [markdown]
# # Compile the model with Contrastive Loss Function

# %%
siamese.compile(loss=loss(margin=margin), optimizer="RMSprop", metrics=["accuracy"])
siamese.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_8 (InputLayer)        [(None, 256, 256, 1)]        0         []
#
#  input_9 (InputLayer)        [(None, 256, 256, 1)]        0         []
#
#  model_4 (Functional)        (None, 10)                   835238    ['input_8[0][0]',
#                                                                      'input_9[0][0]']
#
#  lambda_2 (Lambda)           (None, 1)                    0         ['model_4[0][0]',
#                                                                      'model_4[1][0]']
#
#  batch_normalization_8 (Bat  (None, 1)                    4         ['lambda_2[0][0]']
#  chNormalization)
#
#  dense_5 (Dense)             (None, 1)                    2         ['batch_normalization_8[0][0]'
#                                                                     ]
#
# ==================================================================================================
# Total params: 835244 (3.19 MB)
# Trainable params: 716168 (2.73 MB)
# Non-trainable params: 119076 (465.14 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# # Train Model

# %%
history = siamese.fit(
    [x_train_1, x_train_2],
    y_train,
    validation_data=([x_val_1, x_val_2], y_val),
    batch_size=batch_size,
    epochs=20,
)
# Out:
# Epoch 1/20
# 16/16 [==============================] - 37s 2s/step - loss: 0.2469 - accuracy: 0.6032 - val_loss: 0.3008 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 16/16 [==============================] - 29s 2s/step - loss: 0.2411 - accuracy: 0.6559 - val_loss: 0.3111 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 16/16 [==============================] - 30s 2s/step - loss: 0.2356 - accuracy: 0.7126 - val_loss: 0.3119 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 16/16 [==============================] - 30s 2s/step - loss: 0.2303 - accuracy: 0.7652 - val_loss: 0.3095 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 16/16 [==============================] - 30s 2s/step - loss: 0.2254 - accuracy: 0.7692 - val_loss: 0.3041 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 16/16 [==============================] - 29s 2s/step - loss: 0.2205 - accuracy: 0.7895 - val_loss: 0.2985 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 16/16 [==============================] - 29s 2s/step - loss: 0.2158 - accuracy: 0.8016 - val_loss: 0.2939 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 16/16 [==============================] - 28s 2s/step - loss: 0.2111 - accuracy: 0.7814 - val_loss: 0.2888 - val_accuracy: 0.0000e+00
# Epoch 9/20
# 16/16 [==============================] - 28s 2s/step - loss: 0.2063 - accuracy: 0.8097 - val_loss: 0.2827 - val_accuracy: 0.0000e+00
# Epoch 10/20
# 16/16 [==============================] - 26s 2s/step - loss: 0.2014 - accuracy: 0.8219 - val_loss: 0.2743 - val_accuracy: 0.1409
# Epoch 11/20
# 16/16 [==============================] - 37s 2s/step - loss: 0.1964 - accuracy: 0.8259 - val_loss: 0.2636 - val_accuracy: 0.4027
# Epoch 12/20
# 16/16 [==============================] - 34s 2s/step - loss: 0.1915 - accuracy: 0.8259 - val_loss: 0.2610 - val_accuracy: 0.3960
# Epoch 13/20
# 16/16 [==============================] - 40s 2s/step - loss: 0.1864 - accuracy: 0.8340 - val_loss: 0.2397 - val_accuracy: 0.7047
# Epoch 14/20
# 16/16 [==============================] - 27s 2s/step - loss: 0.1815 - accuracy: 0.8340 - val_loss: 0.2326 - val_accuracy: 0.7517
# Epoch 15/20
# 16/16 [==============================] - 29s 2s/step - loss: 0.1764 - accuracy: 0.8381 - val_loss: 0.2066 - val_accuracy: 0.8591
# Epoch 16/20
# 16/16 [==============================] - 28s 2s/step - loss: 0.1713 - accuracy: 0.8583 - val_loss: 0.2019 - val_accuracy: 0.8725
# Epoch 17/20
# 16/16 [==============================] - 28s 2s/step - loss: 0.1663 - accuracy: 0.8866 - val_loss: 0.1960 - val_accuracy: 0.8792
# Epoch 18/20
# 16/16 [==============================] - 26s 2s/step - loss: 0.1613 - accuracy: 0.8583 - val_loss: 0.1791 - val_accuracy: 0.8926
# Epoch 19/20
# 16/16 [==============================] - 29s 2s/step - loss: 0.1563 - accuracy: 0.8502 - val_loss: 0.1644 - val_accuracy: 0.8993
# Epoch 20/20
# 16/16 [==============================] - 26s 2s/step - loss: 0.1512 - accuracy: 0.9109 - val_loss: 0.1521 - val_accuracy: 0.8993

# %% [markdown]
# # Show and Plot Results

# %%
def plt_metric(history, metric, title, has_valid=True):
    """Plots the given 'metric' from 'history'.

    Arguments:
        history: history attribute of History object returned from Model.fit.
        metric: Metric to plot, a string value present as key in 'history'.
        title: A string to be used as title of plot.
        has_valid: Boolean, true if valid data was passed to Model.fit else false.

    Returns:
        None.
    """
    plt.plot(history[metric])
    if has_valid:
        plt.plot(history["val_" + metric])
        plt.legend(["train", "validation"], loc="upper left")

    plt.title(title)
    plt.ylabel(metric)
    plt.xlabel("epoch")
    plt.show()


# Plot the accuracy
plt_metric(history=history.history, metric="accuracy", title="Model accuracy")
plt.savefig('/content/drive/MyDrive/flatiron/p5_models/siamese_accuracy.png')

# %%
# Plot the contrastive loss
plt_metric(history=history.history, metric="loss", title="Contrastive Loss")
plt.savefig('/content/drive/MyDrive/flatiron/p5_models/siamese_loss.png')

# %%
results = siamese.evaluate([x_test_1, x_test_2], y_test)
print("test loss, test acc:", results)
# Out:
# 4/4 [==============================] - 5s 1s/step - loss: 0.1514 - accuracy: 0.8889
# test loss, test acc: [0.15138952434062958, 0.8888888955116272]

# %% [markdown]
# # Save Model

# %%
siamese.save('/content/drive/MyDrive/flatiron/p5_models/twenty_epochs.keras')
siamese.save('/content/drive/MyDrive/flatiron/p5_models/twenty_epochs.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # Reload Model

# %%
siamese = keras.models.load_model('/content/drive/MyDrive/flatiron/p5_models/twenty_epochs.keras',
                                safe_mode=False,
                                custom_objects={'contrastive_loss': loss})

# %% [markdown]
# # Predictions

# %%
predictions = siamese.predict([x_test_1, x_test_2])
predictions
# Out:
# 4/4 [==============================] - 4s 686ms/step
# array([[0.4623649 ],
#        [0.5604117 ],
#        [0.34443593],
#        [0.3754949 ],
#        [0.38923773],
#        [0.43862206],
#        [0.3331405 ],
#        [0.3415216 ],
#        [0.5604117 ],
#        [0.35580486],
#        [0.40995115],
#        [0.5252675 ],
#        [0.32555845],
#        [0.38249665],
#        [0.36436057],
#        [0.5604117 ],
#        [0.27094606],
#        [0.3210675 ],
#        [0.3839512 ],
#        [0.3192369 ],
#        [0.28163123],
#        [0.5604117 ],
#        [0.42371047],
#        [0.52626765],
#        [0.5270264 ],
#        [0.387446  ],
#        [0.24504197],
#        [0.35280952],
#        [0.34493777],
#        [0.3782888 ],
#        [0.31893927],
#        [0.39644018],
#        [0.5604117 ],
#        [0.35346133],
#        [0.34946418],
#        [0.33046338],
#        [0.3680611 ],
#        [0.35047603],
#        [0.33302373],
#        [0.36228785],
#        [0.36148736],
#        [0.38663593],
#        [0.5505227 ],
#        [0.39712313],
#        [0.23671699],
#        [0.37320796],
#        [0.3454955 ],
#        [0.3672104 ],
#        [0.39926738],
#        [0.54579526],
#        [0.5604117 ],
#        [0.34995654],
#        [0.36249894],
#        [0.5604117 ],
#        [0.5604117 ],
#        [0.33588257],
#        [0.38604876],
#        [0.5604117 ],
#        [0.32485652],
#        [0.38143098],
#        [0.34475604],
#        [0.38058922],
#        [0.5604117 ],
#        [0.37373435],
#        [0.29318982],
#        [0.4472276 ],
#        [0.4115835 ],
#        [0.2546178 ],
#        [0.362192  ],
#        [0.3282775 ],
#        [0.31628373],
#        [0.31881395],
#        [0.33860242],
#        [0.33011347],
#        [0.35981447],
#        [0.33847082],
#        [0.3953877 ],
#        [0.34941852],
#        [0.5604117 ],
#        [0.35982832],
#        [0.35388047],
#        [0.31558895],
#        [0.32536632],
#        [0.35631183],
#        [0.33328533],
#        [0.3784688 ],
#        [0.35370553],
#        [0.36439353],
#        [0.53754014],
#        [0.32095432],
#        [0.3567613 ],
#        [0.32654738],
#        [0.3382041 ],
#        [0.36854857],
#        [0.38613772],
#        [0.37408856],
#        [0.3854242 ],
#        [0.36905754],
#        [0.3454184 ]], dtype=float32)

# %%
predictions = siamese.predict([x_test_1, x_test_2])
visualize(x_test, y_test, to_show=4, predictions=predictions, test=True)
# Out:
# 4/4 [==============================] - 3s 592ms/step

# %% [markdown]
# # Verification Function

# %% [markdown]
# Preprocessing:
#
# The function performs preprocessing on both the input image and validation images. Make sure that the preprocessing steps are consistent with what was used during training the siamese model.
#
# Comparing Shape:
#
# The code checks if the shapes of input_img and validation_img are the same. While this is good for consistency, it might be helpful to log or handle cases where the shapes are different to understand why they might not match.
#
# Result Storage:
#
# The results list stores the model predictions. Ensure that the output shape of the siamese model matches the expected format.
# Detection and Verification:
#
# The code calculates the detection as the number of results above a detection_threshold, and then calculates the verification as the ratio of detection to the total number of results. This gives the percentage of images in the verification set that were detected as known faces. The verified variable is then determined based on a verification_threshold. Ensure these threshold values are chosen appropriately based on the characteristics of your model and dataset.
#
# Result Analysis:
#
# The code finds the index with the minimum score (min_score_index) and retrieves the corresponding name from the names list. This is a way to identify the "closest" match in the verification set.

# %%
# correct verification function
# input picture of me
def verify_image(model, detection_threshold, verification_threshold):
    results = []
    names = []

    verification_images_folder = '/content/drive/MyDrive/flatiron/application_data/verification_images'
    input_img = preprocess_image('/content/drive/MyDrive/flatiron/application_data/input_image/nechama.jpeg')

    for folder in os.listdir(verification_images_folder):
        folder_path = os.path.join(verification_images_folder, folder)
        if not os.path.isdir(folder_path):  # Skip if it's not a directory
            continue
        for image_file in os.listdir(folder_path):
            if image_file.startswith('.'):  # Skip hidden files
                continue
            image_path = os.path.join(folder_path, image_file)
            validation_img = preprocess_image(image_path)

            # Check if input_img and validation_img have the same shape
            if input_img.shape != validation_img.shape:
                # Handle the mismatched shape
                continue

            print(f"Input Image Shape: {input_img.shape}")
            print(f"Validation Image Shape: {validation_img.shape}")

            result = model.predict([np.expand_dims(input_img, axis=0), np.expand_dims(validation_img, axis=0)])
            print(f"Prediction Result: {result}")
            results.append(result)
            names.append(os.path.splitext(folder)[0])

    detection = np.sum(np.array(results) > detection_threshold)
    verification = detection / len(results)
    verified = verification > verification_threshold

    max_score_index = np.argmax(results)
    name_with_max_score = names[max_score_index]

    # min_score_index = np.argmin(results)
    # name_with_min_score = names[min_score_index]

    return results, verified, name_with_max_score


results, verified, max_score_name = verify_image(siamese, 0.5, 0.4)
print(f"Verified: {verified}")
print(f"Welcome {max_score_name}")
# Out:
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 143ms/step
# Prediction Result: [[0.367487]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 89ms/step
# Prediction Result: [[0.40970585]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 205ms/step
# Prediction Result: [[0.46138003]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.44474643]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 76ms/step
# Prediction Result: [[0.42675635]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.3402579]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.32185888]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.40496168]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.3285775]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.28144482]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.3406767]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 50ms/step
# Prediction Result: [[0.34216994]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 72ms/step
# Prediction Result: [[0.30330414]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 43ms/step
# Prediction Result: [[0.30070212]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.32826987]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.32522684]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 77ms/step
# Prediction Result: [[0.32213154]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.38086867]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.35822722]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 71ms/step
# Prediction Result: [[0.3866693]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.3249787]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 48ms/step
# Prediction Result: [[0.3227047]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 76ms/step
# Prediction Result: [[0.31559396]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 60ms/step
# Prediction Result: [[0.31652954]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.32811588]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.3252557]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 78ms/step
# Prediction Result: [[0.28919527]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.34998718]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.26755223]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 43ms/step
# Prediction Result: [[0.30753824]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.34244043]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.39223427]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 126ms/step
# Prediction Result: [[0.4717816]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 48ms/step
# Prediction Result: [[0.46805713]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 78ms/step
# Prediction Result: [[0.45286825]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.45364398]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 84ms/step
# Prediction Result: [[0.46518043]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.4453066]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 78ms/step
# Prediction Result: [[0.45282373]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.40570834]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 75ms/step
# Prediction Result: [[0.3773908]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 48ms/step
# Prediction Result: [[0.38663593]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 79ms/step
# Prediction Result: [[0.3952964]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.37882626]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 43ms/step
# Prediction Result: [[0.43975562]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.47907442]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 43ms/step
# Prediction Result: [[0.4328754]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 43ms/step
# Prediction Result: [[0.31543404]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.42262158]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 69ms/step
# Prediction Result: [[0.43007973]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.40438414]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.34535545]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 52ms/step
# Prediction Result: [[0.31243825]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 83ms/step
# Prediction Result: [[0.41028956]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 65ms/step
# Prediction Result: [[0.38333112]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 74ms/step
# Prediction Result: [[0.33535695]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.3181963]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.35492942]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.34627578]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.34654853]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 54ms/step
# Prediction Result: [[0.3452918]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 73ms/step
# Prediction Result: [[0.35424182]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.32480863]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 55ms/step
# Prediction Result: [[0.33028066]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 73ms/step
# Prediction Result: [[0.3441252]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 48ms/step
# Prediction Result: [[0.30264145]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.32213995]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 49ms/step
# Prediction Result: [[0.3154578]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.3167066]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 95ms/step
# Prediction Result: [[0.29113168]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.31172457]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 57ms/step
# Prediction Result: [[0.32484803]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 65ms/step
# Prediction Result: [[0.32484803]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.2760514]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 57ms/step
# Prediction Result: [[0.2502672]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 49ms/step
# Prediction Result: [[0.32947168]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.3277978]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 86ms/step
# Prediction Result: [[0.32945383]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.32689112]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 49ms/step
# Prediction Result: [[0.30199626]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.30268452]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 74ms/step
# Prediction Result: [[0.32484803]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 43ms/step
# Prediction Result: [[0.24686818]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 69ms/step
# Prediction Result: [[0.38067302]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 66ms/step
# Prediction Result: [[0.27447182]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 51ms/step
# Prediction Result: [[0.32282078]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 50ms/step
# Prediction Result: [[0.32417902]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 61ms/step
# Prediction Result: [[0.35529417]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.3246674]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.32484803]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.32484803]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.3526442]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.46698278]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 49ms/step
# Prediction Result: [[0.41370335]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.45009816]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 68ms/step
# Prediction Result: [[0.43699655]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.40507826]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 43ms/step
# Prediction Result: [[0.38659224]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.42410675]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.45009816]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.27876183]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.27849215]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.3180286]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.32498783]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.3070867]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.3249249]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 71ms/step
# Prediction Result: [[0.3250194]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.32484803]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.32420725]]
# Verified: False
# Welcome Nechama

# %%
results, verified, max_score_name = verify_image(siamese, 0.3, 0.3)
print(f"Verified: {verified}")
print(f"Welcome {max_score_name}")
# Out:
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 49ms/step
# Prediction Result: [[0.367487]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.40970585]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 43ms/step
# Prediction Result: [[0.46138003]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 50ms/step
# Prediction Result: [[0.44474643]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 75ms/step
# Prediction Result: [[0.42675635]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 56ms/step
# Prediction Result: [[0.3402579]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.32185888]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.40496168]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.3285775]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.28144482]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 60ms/step
# Prediction Result: [[0.3406767]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.34216994]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.30330414]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 76ms/step
# Prediction Result: [[0.30070212]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.32826987]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 48ms/step
# Prediction Result: [[0.32522684]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 48ms/step
# Prediction Result: [[0.32213154]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 76ms/step
# Prediction Result: [[0.38086867]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.35822722]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.3866693]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 72ms/step
# Prediction Result: [[0.3249787]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 50ms/step
# Prediction Result: [[0.3227047]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.31559396]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 84ms/step
# Prediction Result: [[0.31652954]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.32811588]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.3252557]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.28919527]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.34998718]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.26755223]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 59ms/step
# Prediction Result: [[0.30753824]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.34244043]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.39223427]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.4717816]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.46805713]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 74ms/step
# Prediction Result: [[0.45286825]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.45364398]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 74ms/step
# Prediction Result: [[0.46518043]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.4453066]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.45282373]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 48ms/step
# Prediction Result: [[0.40570834]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.3773908]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 48ms/step
# Prediction Result: [[0.38663593]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.3952964]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 84ms/step
# Prediction Result: [[0.37882626]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.43975562]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.47907442]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.4328754]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.31543404]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 78ms/step
# Prediction Result: [[0.42262158]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.43007973]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.40438414]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.34535545]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 56ms/step
# Prediction Result: [[0.31243825]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.41028956]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 76ms/step
# Prediction Result: [[0.38333112]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.33535695]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.3181963]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 74ms/step
# Prediction Result: [[0.35492942]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.34627578]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.34654853]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.3452918]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 67ms/step
# Prediction Result: [[0.35424182]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 64ms/step
# Prediction Result: [[0.32480863]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 43ms/step
# Prediction Result: [[0.33028066]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 68ms/step
# Prediction Result: [[0.3441252]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 50ms/step
# Prediction Result: [[0.30264145]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 51ms/step
# Prediction Result: [[0.32213995]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.3154578]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 48ms/step
# Prediction Result: [[0.3167066]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.29113168]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.31172457]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 43ms/step
# Prediction Result: [[0.32484803]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.32484803]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.2760514]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 65ms/step
# Prediction Result: [[0.2502672]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.32947168]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.3277978]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.32945383]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.32689112]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.30199626]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 79ms/step
# Prediction Result: [[0.30268452]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.32484803]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 75ms/step
# Prediction Result: [[0.24686818]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.38067302]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.27447182]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.32282078]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.32417902]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 70ms/step
# Prediction Result: [[0.35529417]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 55ms/step
# Prediction Result: [[0.3246674]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 50ms/step
# Prediction Result: [[0.32484803]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.32484803]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.3526442]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 74ms/step
# Prediction Result: [[0.46698278]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.41370335]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.45009816]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 79ms/step
# Prediction Result: [[0.43699655]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 49ms/step
# Prediction Result: [[0.40507826]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.38659224]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 72ms/step
# Prediction Result: [[0.42410675]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.45009816]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.27876183]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 75ms/step
# Prediction Result: [[0.27849215]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 48ms/step
# Prediction Result: [[0.3180286]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 43ms/step
# Prediction Result: [[0.32498783]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 82ms/step
# Prediction Result: [[0.3070867]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.3249249]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 55ms/step
# Prediction Result: [[0.3250194]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 74ms/step
# Prediction Result: [[0.32484803]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.32420725]]
# Verified: True
# Welcome Nechama

# %%
# could delete this after just trying it with less verification images
results, verified, max_score_name = verify_image(siamese, 0.3, 0.3)
print(f"Verified: {verified}")
print(f"Welcome {max_score_name}")
# Out:
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 49ms/step
# Prediction Result: [[0.367487]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 75ms/step
# Prediction Result: [[0.46138003]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.44474643]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 73ms/step
# Prediction Result: [[0.42675635]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.40496168]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.3406767]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 75ms/step
# Prediction Result: [[0.34216994]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 48ms/step
# Prediction Result: [[0.30330414]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.32826987]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 49ms/step
# Prediction Result: [[0.32213154]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.3249787]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 94ms/step
# Prediction Result: [[0.3227047]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.31559396]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 48ms/step
# Prediction Result: [[0.32811588]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 85ms/step
# Prediction Result: [[0.3252557]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 53ms/step
# Prediction Result: [[0.34244043]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 88ms/step
# Prediction Result: [[0.46805713]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 49ms/step
# Prediction Result: [[0.45364398]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.46518043]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 50ms/step
# Prediction Result: [[0.45282373]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.3773908]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 142ms/step
# Prediction Result: [[0.47907442]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 69ms/step
# Prediction Result: [[0.4328754]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.42262158]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.43007973]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 49ms/step
# Prediction Result: [[0.34535545]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.31243825]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 50ms/step
# Prediction Result: [[0.41028956]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 49ms/step
# Prediction Result: [[0.38333112]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 67ms/step
# Prediction Result: [[0.3181963]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.35424182]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.32480863]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 49ms/step
# Prediction Result: [[0.33028066]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.3441252]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.29113168]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 74ms/step
# Prediction Result: [[0.32484803]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.2760514]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 48ms/step
# Prediction Result: [[0.2502672]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 63ms/step
# Prediction Result: [[0.3277978]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.32689112]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 51ms/step
# Prediction Result: [[0.32282078]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.32417902]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 80ms/step
# Prediction Result: [[0.3246674]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 59ms/step
# Prediction Result: [[0.32484803]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 81ms/step
# Prediction Result: [[0.32484803]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 58ms/step
# Prediction Result: [[0.3526442]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.46698278]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 78ms/step
# Prediction Result: [[0.45009816]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.40507826]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 50ms/step
# Prediction Result: [[0.42410675]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 79ms/step
# Prediction Result: [[0.27876183]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 48ms/step
# Prediction Result: [[0.27849215]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 49ms/step
# Prediction Result: [[0.3180286]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.32498783]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.3070867]]
# Verified: True
# Welcome Nechama

# %% [markdown]
# So the first try i wasnt verified but it found me as the right name, so i switched the thresholds and now it verifies correctly.
#
# Now trying a picture of Julie.

# %%
def verify_image_julie(model, detection_threshold, verification_threshold):
    results = []
    names = []

    verification_images_folder = '/content/drive/MyDrive/flatiron/application_data/verification_images'
    input_img = preprocess_image('/content/drive/MyDrive/flatiron/application_data/input_image/julie.jpeg')

    for folder in os.listdir(verification_images_folder):
        folder_path = os.path.join(verification_images_folder, folder)
        if not os.path.isdir(folder_path):  # Skip if it's not a directory
            continue
        for image_file in os.listdir(folder_path):
            if image_file.startswith('.'):  # Skip hidden files
                continue
            image_path = os.path.join(folder_path, image_file)
            validation_img = preprocess_image(image_path)

            # Check if input_img and validation_img have the same shape
            if input_img.shape != validation_img.shape:
                # Handle the mismatched shape
                continue

            print(f"Input Image Shape: {input_img.shape}")
            print(f"Validation Image Shape: {validation_img.shape}")

            result = model.predict([np.expand_dims(input_img, axis=0), np.expand_dims(validation_img, axis=0)])
            print(f"Prediction Result: {result}")
            results.append(result)
            names.append(os.path.splitext(folder)[0])

    detection = np.sum(np.array(results) > detection_threshold)
    verification = detection / len(results)
    verified = verification > verification_threshold

    max_score_index = np.argmax(results)
    name_with_max_score = names[max_score_index]

    return results, verified, name_with_max_score

results, verified, max_score_name = verify_image_julie(siamese, 0.3, 0.3)
print(f"Verified: {verified}")
print(f"Welcome {max_score_name}")
# Out:
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.3972739]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.44604176]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.4519951]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.44496864]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 81ms/step
# Prediction Result: [[0.419452]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.37952262]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.37156063]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.37336686]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 82ms/step
# Prediction Result: [[0.38168418]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.36238837]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 71ms/step
# Prediction Result: [[0.3677951]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 58ms/step
# Prediction Result: [[0.36822137]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.3567486]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 72ms/step
# Prediction Result: [[0.3794507]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 43ms/step
# Prediction Result: [[0.3829014]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 82ms/step
# Prediction Result: [[0.40097344]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.4545566]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 79ms/step
# Prediction Result: [[0.4489939]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 43ms/step
# Prediction Result: [[0.4617405]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.47007576]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 43ms/step
# Prediction Result: [[0.36194453]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 57ms/step
# Prediction Result: [[0.45721698]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 79ms/step
# Prediction Result: [[0.42486456]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.46456495]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 71ms/step
# Prediction Result: [[0.42518178]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.37458128]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.3501243]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.42602593]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.42406902]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.3633534]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.38210922]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.32308885]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.3342589]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 43ms/step
# Prediction Result: [[0.36528942]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 52ms/step
# Prediction Result: [[0.3599589]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 72ms/step
# Prediction Result: [[0.37708756]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 43ms/step
# Prediction Result: [[0.33515632]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.29460672]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 74ms/step
# Prediction Result: [[0.39429218]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 108ms/step
# Prediction Result: [[0.36012024]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.37425593]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 52ms/step
# Prediction Result: [[0.37626886]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.37683454]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.37708756]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 75ms/step
# Prediction Result: [[0.37708756]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 50ms/step
# Prediction Result: [[0.39069778]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 59ms/step
# Prediction Result: [[0.42733133]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 78ms/step
# Prediction Result: [[0.4572452]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 44ms/step
# Prediction Result: [[0.43373892]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 45ms/step
# Prediction Result: [[0.47866112]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 83ms/step
# Prediction Result: [[0.32772994]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 47ms/step
# Prediction Result: [[0.3274014]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 48ms/step
# Prediction Result: [[0.37400123]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 70ms/step
# Prediction Result: [[0.3771075]]
# Input Image Shape: (256, 256)
# Validation Image Shape: (256, 256)
# 1/1 [==============================] - 0s 46ms/step
# Prediction Result: [[0.36182082]]
# Verified: True
# Welcome Sunny
